# %% [raw]
# Let's see the titanic dataset, clean it, analyse the data and draw some conclusions!

# %%
#getting the required libreries
import pandas as pd
from io import StringIO 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#fetching some titanic dataset rows
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(titanic.shape)
titanic.info()
# Out:
# (891, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [raw]
# Observations:
# -> There are total 891 rows and 12 columns in the titanic dataset
#
# Data Dictionery:
# PassengerId - Id of the Passenger on the ship
# Survived    - Whether the Passenger Survived or not
#                           0 = did not survive (dead)
#                           1 = survived (alive)
# Pclass      - Passenger Class on the ship
#                           1 = First Class
#                           2 = Second Class
#                           3 = Third Class
# Name        - First and Last Name
# Sex         - Gender Male or Female
# Age         - Age
# SibSp       - Number of Siblings or Spouses aboard
# Parch       - Number of Parents or Children aboard
# Ticket      - Ticket Number
# Fare        - Ticket Fare
# Cabin       - Cabin number
# Embarked    - Port of Embarkation
#               C = Cherbourg; Q = Queenstown; S = Southampton

# %%
print(titanic.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [raw]
# Observations:
# -> There are three columns named Age, Cabin and Embarked having null values
# -> We will remove(drop) 'Cabin' column from the titanic dataset since it has highest null values
#    and of no much importance
# -> We will replace the null values of 'Age' and 'Embarked' columns with
#    suitable new values to perform proper analysis

# %%
dataLabels = sns.boxplot(y='Age',x='Pclass',data=titanic,palette='viridis_r')
def replaceNullAge(cols):
    age = cols[0]
    pclass= cols[1]
    medians = titanic.groupby(['Pclass'])['Age'].median()
    if pd.isnull(age):
        if pclass == 1:
            return medians.iloc[0]
        elif pclass==2:
            return medians.iloc[1]
        else:
            return medians.iloc[2]
    else:
        return age

# %%
titanic['Age'] = titanic[['Age','Pclass']].apply(replaceNullAge,axis=1)
#one hot encoding technique
print(titanic['Embarked'].unique()) 
sns.countplot(x='Embarked',data=titanic,palette='viridis_r')
embarked_dummies=pd.get_dummies(titanic['Embarked'],drop_first=True)
titanic.drop(['Embarked','PassengerId','Ticket','Cabin'],axis=1,inplace=True) # drop unnecessary columns 
titanic = pd.concat([titanic,embarked_dummies],axis=1) # concate encoded column embarked_dummies
print(titanic.isnull().sum())
# Out:
# ['S' 'C' 'Q' nan]
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Q           0
# S           0
# dtype: int64

# %%
fareBox = sns.boxplot(x='Fare',data=titanic,palette='viridis_r')
def replaceZeroFare(col):
    fare = col[0] 
    if fare == 0:
        return titanic['Fare'].median()
    else:
        return fare
zeroFareCount = titanic.loc[(titanic['Fare'] == 0)].count()
if zeroFareCount['Fare'] > 0:
    titanic['Fare'] = titanic[['Fare']].apply(replaceZeroFare,axis=1)
else:
    print("No replacement needed in Fare column")

# %% [raw]
# Observations:
# -> Removed or dropped 'Ticket,'Cabin' column since they were not important
# -> Replaced Age column's null values with appropriate dummy age values (Age median value with respect    to different Passenger Classes)
# -> Dropped Embarked column and added two new columns Q and S with One hot Encoding technique
# -> Replaced null or Nan Fare values with its median value

# %%
sns.heatmap(titanic.isnull(),cmap='viridis')
plt.show()

# %% [raw]
# Observations:
# -> from the heatmap, we can infer that we have removed all null or Nan values from all the columns
#    now we can start the data analysis on the clean dataset

# %%
titanic[['Age','Fare','SibSp','Parch']].describe()
# Out:
#               Age        Fare       SibSp       Parch
# count  891.000000  891.000000  891.000000  891.000000
# mean    29.066409   32.447545    0.523008    0.381594
# std     13.244532   49.570235    1.102743    0.806057
# min      0.420000    4.012500    0.000000    0.000000
# 25%     22.000000    7.925000    0.000000    0.000000
# 50%     26.000000   14.454200    0.000000    0.000000
# 75%     37.000000   31.000000    1.000000    0.000000
# max     80.000000  512.329200    8.000000    6.000000

# %% [raw]
# Observations:
# -> There were all kinds of paasengers on the ship from 5 months old babies to 80 year olds
# -> Average passenger age was 29 years meaning there were more young adults on the ship
#    compared to seniors
# -> Average ticket fare for travelling in titanic was around $32
# -> Maximum ticket fare was around $512 where as minimum was $4
# -> Titanic had passengers travelling with their friends and families too
# -> Maximum number of siblings or spouse with the passenger was 8
# -> Passenger with number of parents or children aboard was 6 but overall, passengers were travelling    alone too

# %%
tdf = titanic.copy()
youngest = tdf.loc[tdf['Age'] == min(tdf['Age'])]
print(youngest[['Name','Age','Pclass','Q','S','Survived','SibSp','Parch','Fare']].to_string(index=False))
oldest = tdf.loc[tdf['Age'] == max(tdf['Age'])]                               
print(oldest[['Name','Age','Pclass','Q','S','Survived','SibSp','Parch','Fare']].to_string(index=False))
# Out:
#                            Name  Age  Pclass  Q  S  Survived  SibSp  Parch   Fare
# Thomas, Master. Assad Alexander 0.42       3  0  0         1      0      1 8.5167
#                                 Name  Age  Pclass  Q  S  Survived  SibSp  Parch  Fare
# Barkworth, Mr. Algernon Henry Wilson 80.0       1  0  1         1      0      0  30.0

# %% [raw]
# Observations:
# -> Thomas, Master. Assad Alexander was the youngest passenger (nearly 5 months)
#    embarked the journey from Cherbourg in the Third class with a single parent
# -> Barkworth, Mr. Algernon Henry Wilson was the oldest passenger (80 years)
#    embarked the journey from Southampton in the First class
# -> Both survived the sink

# %%
#2. between 30 to 60 age with passenger name
DfAge = tdf.loc[(tdf['Age'] >= 0) & (tdf['Age'] <= 20)]
print("Passenger Names with Age between 30 and 60:")
print(DfAge[['Name','Age']])
axAge = tdf['Age'].plot.hist(x='Age', rot=0,bins=5, color="red",figsize=(5,2.5))
axAge.set_title("Distribution of Age in Titanic")
axAge.set_xlabel("Age")
axAge.set_ylabel("Count of Passengers")
total = tdf['Age'].count()
for p in axAge.patches:
    h = p.get_height()
    w = p.get_width()
    x = p.get_x()
    y = p.get_y()
    axAge.annotate(str(round((h*100)/total,1))+"%",xy=(x + w/2,h))
# Out:
# Passenger Names with Age between 30 and 60:
#                                      Name   Age
# 7          Palsson, Master. Gosta Leonard   2.0
# 9     Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10        Sandstrom, Miss. Marguerite Rut   4.0
# 12         Saundercock, Mr. William Henry  20.0
# 14   Vestrom, Miss. Hulda Amanda Adolfina  14.0
# ..                                    ...   ...
# 869       Johnson, Master. Harold Theodor   4.0
# 875      Najib, Miss. Adele Kiamie "Jane"  15.0
# 876         Gustafsson, Mr. Alfred Ossian  20.0
# 877                  Petroff, Mr. Nedelio  19.0
# 887          Graham, Miss. Margaret Edith  19.0
#
# [179 rows x 2 columns]

# %% [raw]
# Observations:
# -> 55% of the passengers were young means between 15 to 30 years
# -> 33% of the passengers were adults between 30 to 60 years
# -> only 1% were senior citizens on the ship while 11% of the passengers were children from babies to    teens

# %%
#3. Find out how many survived and not survived
number = tdf['Survived'].value_counts()
print("Number of Survived Passengers:",number[1])
print("Number of Not Survived(Dead) Passengers:",number[0])
# Out:
# Number of Survived Passengers: 342
# Number of Not Survived(Dead) Passengers: 549

# %%
#4. Find out how many males and females have travelled
number = tdf['Sex'].value_counts()
print("Number of Male Passengers:",number[0])
print("Number of Female Passengers:",number[1])
# Out:
# Number of Male Passengers: 577
# Number of Female Passengers: 314

# %%
pclass = tdf['Pclass'].value_counts().sort_index()
df = pd.DataFrame({'Passenger Class':pclass.index, 'Number of Passengers':pclass.values})
ax = df.plot.bar(x='Passenger Class', rot=0, color="green",figsize=(6,3))
ax.set_title("Distribution of Passengers over Classes in Titanic")
ax.set_xlabel("Passenger Classes")
ax.set_ylabel("Number of Passengers")
for p in ax.patches:
    h = p.get_height()
    w = p.get_width()
    x = p.get_x()
    y = p.get_y()
    ax.annotate(h,xy=(x + w/2,h))

# %% [raw]
# Observations:
# -> People preferred Third class of the Titanic for travelling compared to other two classes
# -> 55% of Passengers were from Third class
#    while 24% and 21% were from First and Second class respectively

# %%
gender = tdf['Sex'].value_counts()
total = gender.sum()
ax = gender.plot.bar('Sex',color='purple',figsize=(5,3))
ax.set_title("Gender Distribution in Titanic")
ax.set_xlabel("Passenger's Gender")
ax.set_ylabel("Number of Males/Females")
for p in ax.patches:
    h = p.get_height()
    w = p.get_width()
    x = p.get_x()
    y = p.get_y()
    ax.annotate(h,xy=(x + w/2,h))
    ax.annotate(str(round((h*100)/total)) + "%",xy=(x+w/2,y+h/2),ha='center')

# %%
young = tdf[tdf['Age']<18]['Sex'].value_counts()
adult = tdf[(tdf['Age']>=18) & (tdf['Age']<=59)]['Sex'].value_counts()
senior = tdf[tdf['Age']>59]['Sex'].value_counts()
ageDf = pd.DataFrame({'Young [0-17 years]': young.values, 'Adult [18-59 years]': adult.values, 
                      'Senior [60-80 years]': senior.values},
                       index=['Male','Female'])
ageRangeAx = ageDf.plot.bar(stacked=True,rot=0, figsize=(6,3))
ageRangeAx.set_title("Gender wise Age distribution in Titanic")
ageRangeAx.set_xlabel("Gender")
ageRangeAx.set_ylabel("Count of Passengers in different ages")
for p in ageRangeAx.patches:
    h = p.get_height()
    w = p.get_width()
    x = p.get_x()
    y = p.get_y()
    ageRangeAx.annotate(str(round(h)),xy=(x+w/2,y+h/2),ha='center')

# %% [raw]
# Observations:
# -> 65% of the Passengers were Males while only 35% of them were females
# -> 56% of the total passengers were male adults while 29% of them were female adults with age between      18 to 59 years
# -> Only 13% of the total passengers were youngsters below 18 years of age
# -> Only 3% of the total passengers were senior citiens out of which 22 were male seniors and 4          females seniors

# %%
survived = tdf['Survived'].value_counts()
survived.values
total = survived.sum()
df = pd.DataFrame({'Survived':survived.values},index=['Dead','Survived'])
ax = df.plot.bar(y='Survived',rot=0, color="red", figsize=(6,3),legend=False)
ax.set_title("Passenger Survival in Titanic")
ax.set_xlabel("Survival Status")
ax.set_ylabel("Number of Passengers")
for p in ax.patches:
    h = p.get_height()
    w = p.get_width()
    x = p.get_x()
    y = p.get_y()
    ax.annotate(str(round((h*100)/total)) + "%",xy=(x + w/2,h))
    ax.annotate(str(h),xy=(x+w/2,y+h/2),ha='center')

# %%
data = tdf[['Sex','Survived']].value_counts().sort_index()
male = data['male'].values
female = data['female'].values
df = pd.DataFrame({'Male': male, 'Female': female},index=['Dead','Survived'])
ax = df.plot.bar(stacked=True,rot=0, color={'Male':'green', 'Female': 'violet'})
for p in ax.patches:
    h = p.get_height()
    w = p.get_width()
    x = p.get_x()
    y = p.get_y()
    ax.annotate(str(round(h)),xy=(x+w/2,y+h/2),ha='center')

# %%
#5. Survived column with how many females or males survived
data = tdf.loc[tdf['Survived'] == 1,['Sex']].value_counts()
df = pd.DataFrame({'Male': data['male'], 'Female': data['female']},index=['Survived'])
ax = df.plot.bar(rot=0, figsize=(6,3), color={'Male':'blue', 'Female':'#FF00FF'})
for p in ax.patches:
    h = p.get_height()
    w = p.get_width()
    x = p.get_x()
    y = p.get_y()
    ax.annotate(str(round(h)),xy=(x+w/2,y+h/2),ha='center')
    ax.annotate(str(round((h*100)/data.sum())) + "%",xy=(x+w/2,h),ha='center')

# %% [raw]
# Observations:
# -> 62% of total passengers could not survive the titanic mishap
#    while 38% could be alive after the sink
# -> Out of survived passengers, 233 (68%) were females and rest 109 were males
# -> Out of dead passengers, 468 were males while 81 were females
# -> It clearly states  children and females were given first preference under titanic rescue              operations

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax = sns.countplot(x='Pclass',hue='Survived',data=tdf,palette=['red','blue'], alpha=0.8)
ax.set(
   title='Passenger CLass: Survived Vs Dead',
   xlabel='Passenger\'s Class',
   ylabel='Count of Passengers',
   xticklabels = ['First','Second','Third']
)
ax.legend(title='Survival', labels=['Dead','Alive'])
for p in ax.patches:
    h = p.get_height()
    x = p.get_x()
    w = p.get_width()
    ax.annotate(h, (x+0.15, h))
plt.show()

# %% [raw]
# Observations:
# -> It seems maximum number of first class (136) passengers survived out of all other passenger          classes on the ship
# -> 55% (491) of total passengers took third class ticket and out of which 372 passengers could not      survive.
# -> 21% (184) of total passengers took second class ticket out of which only 87 passengers could          survive

# %%
pAx = sns.countplot(x='Pclass',hue='Sex',data=tdf,palette=['#00008B','#FF4040'])
pAx.set(
   title='Passenger CLass: Male Vs Female',
   xlabel='Passenger\'s Class',
   ylabel='Count of Passengers',
   xticklabels = ['First','Second','Third']
)
pAx.legend(title='Gender', labels=['Men','Women'])
for p in pAx.patches:
    h = p.get_height()
    x = p.get_x()
    w = p.get_width()
    pAx.annotate(h, (x+0.15, h))
plt.show()

# %% [raw]
# Observations:
# -> highest number of males and females(55% of all) were from the third class on the ship
#    (347 males and 144 females)
# -> 24% and 21% passengers were from first and second class respectively out of which
#    first class had 13% more men and 24% more women compared to second class

# %%
fareAx = sns.displot(tdf['Fare'],kde=True,bins=10,color='red')
#kde kernal density estimation
fareFacet = fareAx.facet_axis(0,0)
for e in fareFacet.containers:
    fares = [v.get_height() for v in e]
    #females = [v.get_x() for v in e]
    fareFacet.bar_label(e, labels=fares, label_type='edge')

# %% [raw]
# Observations:
# -> 84% of the passengers had bought the ticket fare under $50
# -> 9.9% of the passengers bought the ticket between $50 to $100
# -> Below 6% of the passengers had paid $100 to $300 for their tickets
# -> 0.33% only meaning 3 of the passengers bought the ticket for more than $500

# %%
catAx = sns.catplot(x='Pclass',hue='Sex',col='Survived',data=tdf,kind='count')
catAx.set(
    xticklabels = ['First','Second','Third']
 )
survived_0 = catAx.facet_axis(0,0)
for e in survived_0.containers:
    males = [v.get_height() for v in e]
    females = [v.get_x() for v in e]
    survived_0.bar_label(e, labels=males, label_type='edge')
survived_1 = catAx.facet_axis(0,1)
for e in survived_1.containers:
    males = [v.get_height() for v in e]
    females = [v.get_x() for v in e]
    survived_1.bar_label(e, labels=males, label_type='edge')
plt.show()

# %% [raw]
# Obeservations:
# -> 300 males alone from third class have not survived the titanic mishap
#    while most of the females (233) have been rescued from or survived the sink
# -> Passengers from Third class could not be saved compared to First and second class on the ship
# -> Surprisingly, positive Survival rate in second class for males is low compared to third class
#    while for females, highest positive rate is from first class

# %%
ax = sns.stripplot(x=tdf['Pclass'],y=tdf['Fare'])
plt.show()

# %% [raw]
# Observations:
# -> First Class Ticket fare on the ship was highest while second and third class fares ranged almost      same
# -> Particularly,
#     1. First class ticket fare ranged from $5 to $512
#     2. Second class ticket fare ranged from $10.5 to $73.5
#     3. Third class ticket fare ranged from $4 to $69.55

# %%
sns.stripplot(x=tdf['Survived'],y=tdf['Fare'])
plt.show()

# %% [raw]
# Observations:
# -> We can see from the chart above that there is no relation between ticket fare and the survival status of the passengers
# -> Whatever the fare was, higher or lower, there is no impact on how they got rescued from the sink
# -> Passengers who paid higher fare, could not be saved or passengers who paid lower fare could be saved too

# %%
sns.stripplot(x=tdf['Parch'],y=tdf['Fare'])
plt.show()

# %% [raw]
# Observations:
# -> 98% of the passengers were travelling with 2,1 or no parents or children on board paying the ticket fare between $4 to $300
# -> Few passengers are travelling with 3 children or parents on board
# -> Very few passengers have more than 6,5 or 4 parents or children on board

# %%
sibSpAx = sns.countplot(x='SibSp',data=tdf)
for p in sibSpAx.patches:
    h = p.get_height()
    x = p.get_x()
    w = p.get_width()
    sibSpAx.annotate(h, (x+0.15, h))
plt.show()
#SibSp count

# %% [raw]
# Obervations:
# -> More than 600 passengers travelled without any siblings or spouse
# -> While 209 people travelled with one sibling or spouse
# -> There were some people around 5% who travelled with families with more than 3-8 siblings
